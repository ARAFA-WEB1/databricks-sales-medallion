# %%
from pyspark.sql.functions import *

# %%
df = spark.read.format("csv")\
    .option('header','True')\
    .option('delimeter',',')\
    .option('inferSchema','True')\
    .load('/Volumes/workspace/depi/depi_volume/sales_data.csv')

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = df.withColumn('DataSource' , lit('Sales_data'))
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.mode('overwrite').format('delta').saveAsTable('depi_bronze_sales')

# %%
spark.sql("USE depi")
# Out:
# DataFrame[]

# %%
df.write.mode('overwrite').format('delta').saveAsTable('depi.bronze_sales')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6084693082274957>, line 1
# ----> 1 df.write.mode('overwrite').format('delta').saveAsTable('depi.bronze_sales')
#
# NameError: name 'df' is not defined
